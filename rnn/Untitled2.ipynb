# %%
from gensim.test.utils import get_tmpfile
from gensim.models import Word2Vec
import numpy as np
import nltk
import glob
import csv
import pandas as pd

# 读取文件至字符串形式： glob、with+open、
negnames = glob.glob('./train/neg/*.txt')
posnames = glob.glob('./train/pos/*.txt')
filenames = negnames + posnames
negdocuments = []
posdocuments = []
for filename in negnames:
    with open(filename, encoding='utf-8') as document:
        negdocuments.append(document.read())
for filename in posnames:
    with open(filename, encoding='utf-8') as document:
        posdocuments.append(document.read())
# Out:
#        label:                                              text:
# 0           0  Story of a man who has unnatural feelings for ...
# 1           0  Airport '77 starts as a brand new luxury 747 p...
# 2           0  This film lacked something I couldn't put my f...
# 3           0  Sorry everyone,,, I know this is supposed to b...
# 4           0  When I was little my parents took me along to ...
# 5           0  "It appears that many critics find the idea of...
# 6           0  The second attempt by a New York intellectual ...
# 7           0  I don't know who to blame, the timid writers o...
# 8           0  This film is mediocre at best. Angie Harmon is...
# 9           0  The film is bad. There is no other way to say ...
# 10          0  This film is one giant pant load. Paul Schrade...
# 11          0  The plot for Descent, if it actually can be ca...
# 12          0  Plot is not worth discussion even if it hints ...
# 13          0  This film is about a male escort getting invol...
# 14          0  This movie must be in line for the most boring...
# 15          0  A worn-out plot of a man who takes the rap for...
# 16          0  I saw this movie at a drive-in in 1959. Until ...
# 17          0  Ghost of Dragstrip Hollow is a typical 1950's ...
# 18          0  "Ghost of Dragstrip Hollow" was one of the man...
# 19          0  "Ghost of Dragstrip Hollow" appears to take pl...
# 20          0  The characters are unlikeable and the script i...
# 21          0  Kareena Kapoor in a bikini hmmmmmmmm.<br /><br...
# 22          0  I rented this on DVD and I kind of feel bad si...
# 23          0  Vijay Krishna Acharya's 'Tashan' is a over-hyp...
# 24          0  The worst movie I have seen since Tera Jadoo C...
# 25          0  Summer season is here when the choices in the ...
# 26          0  Shame on Yash Raj films and Aditya Chopra who ...
# 27          0  First lesson that some film makers (particular...
# 28          0  If this is a 2008 product from one of the bigg...
# 29          0  I had some expectation for the movie, since it...
# ...       ...                                                ...
# 12470       0  I remember watching this movie several times a...
# 12471       0  The first scene in 'Problem Child' has a baby ...
# 12472       0  This kid is rather bad, but in no way do they ...
# 12473       0  My girlfriend and I were stunned by how bad th...
# 12474       0  This is one of the worst movies I have ever se...
# 12475       0  Having just recently re-viewed "Lipstick" for ...
# 12476       0  Don't waste 90 minutes of your time on "Fast F...
# 12477       0  This movie was billed as a comedy and a myster...
# 12478       0  Story starts slow and nothing funny happens fo...
# 12479       0  This film is a massive Yawn proving that Ameri...
# 12480       0  It was a Sunday night and I was waiting for th...
# 12481       0  Have I ever seen a film more shockingly inept?...
# 12482       0  The next time you are at a party and someone a...
# 12483       0  Turgid dialogue, feeble characterization - Har...
# 12484       0  Cameron Diaz is a woman who is married to a ju...
# 12485       0  I had the misfortune to watch this rubbish on ...
# 12486       0  It's pretty bad when the generic movie synopsi...
# 12487       0  Having watched this movie on the SciFi channel...
# 12488       0  First off, I'm not here to dog this movie. I f...
# 12489       0  Ah yez, the Sci Fi Channel produces Yeti anoth...
# 12490       0  Yeti: Curse of the Snow Demon starts aboard a ...
# 12491       0  Hmmm, a sports team is in a plane crash, gets ...
# 12492       0  I saw this piece of garbage on AMC last night,...
# 12493       0  Although the production and Jerry Jameson's di...
# 12494       0  Capt. Gallagher (Lemmon) and flight attendant ...
# 12495       0  Towards the end of the movie, I felt it was to...
# 12496       0  This is the kind of movie that my enemies cont...
# 12497       0  I saw 'Descent' last night at the Stockholm Fi...
# 12498       0  Some films that you pick up for a pound turn o...
# 12499       0  This is one of the dumbest films, I've ever se...
#
# [12500 rows x 2 columns]

# %%
# 写入csv
negdataframe = pd.DataFrame({'text:' : negdocuments, 'label:' : 0})
posdataframe = pd.DataFrame({'text:' : posdocuments, 'label:' : 1})
dataframe = negdataframe + posdataframe
negdataframe
