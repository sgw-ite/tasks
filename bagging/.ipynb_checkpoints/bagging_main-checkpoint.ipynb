# %%
import numpy as np
import Feature_Engineering
from DTClassifier import DTClassifier as DTC
from LClassifier import LClassifier as LRC
import train_test_split as tts
from LSVMClassifier import LSVMClassifier as LSVMC
import metrics
from sklearn.ensemble import BaggingClassifier
# Out:
# /home/sgw/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
X_train, y_train = Feature_Engineering.datatransform(file='./train.csv')
X_train, y_train, X_test, y_test = tts.bootstrapping(X_train, y_train)

# %%
dtc = DTC(max_gini=0.27, min_samples=6)
lrc = LRC()
lsvmc = LSVMC()

# %%
dtc.fit(X_train, y_train)
lrc.fit(X_train, y_train)
lsvmc.fit(X_train, y_train)
# Out:
# /home/sgw/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/sgw/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-21-92a250e74de1> in <module>()
# ----> 1 dtc.fit(X_train, y_train)
#       2 lrc.fit(X_train, y_train)
#       3 lsvmc.fit(X_train, y_train)
#
# ~/tasks/bagging/DTClassifier.py in fit(self, X_train, y_train)
#      63
#      64     def fit(self, X_train, y_train):
# ---> 65         self.Tree = self._CreateTree(X_train, y_train)
#      66         return self
#      67
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      54                 Tree = {(d,value,0):np.median(y_l), (d,value,1):np.median(y_r)}
#      55             else:
# ---> 56                 Tree = {(d,value,0):np.median(y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      54                 Tree = {(d,value,0):np.median(y_l), (d,value,1):np.median(y_r)}
#      55             else:
# ---> 56                 Tree = {(d,value,0):np.median(y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      54                 Tree = {(d,value,0):np.median(y_l), (d,value,1):np.median(y_r)}
#      55             else:
# ---> 56                 Tree = {(d,value,0):np.median(y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
# ---> 61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      62         return Tree
#      63
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      54                 Tree = {(d,value,0):np.median(y_l), (d,value,1):np.median(y_r)}
#      55             else:
# ---> 56                 Tree = {(d,value,0):np.median(y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      54                 Tree = {(d,value,0):np.median(y_l), (d,value,1):np.median(y_r)}
#      55             else:
# ---> 56                 Tree = {(d,value,0):np.median(y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
# ---> 59                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):np.median(y_r)}
#      60             else:
#      61                 Tree = {(d,value,0):self._CreateTree(X_l, y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      54                 Tree = {(d,value,0):np.median(y_l), (d,value,1):np.median(y_r)}
#      55             else:
# ---> 56                 Tree = {(d,value,0):np.median(y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
#
# ... last 1 frames repeated, from the frame below ...
#
# ~/tasks/bagging/DTClassifier.py in _CreateTree(self, X, y)
#      54                 Tree = {(d,value,0):np.median(y_l), (d,value,1):np.median(y_r)}
#      55             else:
# ---> 56                 Tree = {(d,value,0):np.median(y_l), (d,value,1):self._CreateTree(X_r, y_r)}
#      57         else:
#      58             if ((self._gini(y_r) <= self.max_gini) or (len(y_r)<=self.min_samples)):
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
dtc.score(X_test, y_test), lrc.score(X_test, y_test), lsvmc.score(X_test, y_test)
# Out:
# (0.6067415730337079, 0.6179775280898876, 0.4157303370786517)

# %%
y_pred = np.array((dtc.predict(X_test) + lrc.predict(X_test) + lsvmc.predict(X_test))>=2,dtype='int')
metrics.acc_score(y_pred, y_test)
# Out:
# 0.7940074906367042

# %%
X, y = Feature_Engineering.datatransform(file='./train.csv')
X_train, y_train, X_test, y_test = tts.bootstrapping(X, y)
dtc.fit(X_train, y_train)
X_train, y_train, X_test, y_test = tts.bootstrapping(X, y)
lrc.fit(X_train, y_train)
X_train, y_train, X_test, y_test = tts.bootstrapping(X, y)
lsvmc.fit(X_train, y_train)
y_pred = np.array((dtc.predict(X_test) + lrc.predict(X_test) + lsvmc.predict(X_test))>=2,dtype='int')
metrics.acc_score(y_pred, y_test)
# Out:
# 0.6067415730337079
