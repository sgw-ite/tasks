# %%
import numpy as np
import pickle
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-44d8fef7c19e> in <module>()
#       1 import numpy as np
#       2 import pickle
# ----> 3 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
file = './cifar10/data_batch_1'

# %%
with open(file,'rb') as fo:
    data = pickle.load(fo,encoding='bytes')
data[b'labels']
# Out:
# [6,
#  9,
#  9,
#  4,
#  1,
#  1,
#  2,
#  7,
#  8,
#  3,
#  4,
#  7,
#  7,
#  2,
#  9,
#  9,
#  9,
#  3,
#  2,
#  6,
#  4,
#  3,
#  6,
#  6,
#  2,
#  6,
#  3,
#  5,
#  4,
#  0,
#  0,
#  9,
#  1,
#  3,
#  4,
#  0,
#  3,
#  7,
#  3,
#  3,
#  5,
#  2,
#  2,
#  7,
#  1,
#  1,
#  1,
#  2,
#  2,
#  0,
#  9,
#  5,
#  7,
#  9,
#  2,
#  2,
#  5,
#  2,
#  4,
#  3,
#  1,
#  1,
#  8,
#  2,
#  1,
#  1,
#  4,
#  9,
#  7,
#  8,
#  5,
#  9,
#  6,
#  7,
#  3,
#  1,
#  9,
#  0,
#  3,
#  1,
#  3,
#  5,
#  4,
#  5,
#  7,
#  7,
#  4,
#  7,
#  9,
#  4,
#  2,
#  3,
#  8,
#  0,
#  1,
#  6,
#  1,
#  1,
#  4,
#  1,
#  8,
#  3,
#  9,
#  6,
#  6,
#  1,
#  8,
#  5,
#  2,
#  9,
#  9,
#  8,
#  1,
#  7,
#  7,
#  0,
#  0,
#  6,
#  9,
#  1,
#  2,
#  2,
#  9,
#  2,
#  6,
#  6,
#  1,
#  9,
#  5,
#  0,
#  4,
#  7,
#  6,
#  7,
#  1,
#  8,
#  1,
#  1,
#  2,
#  8,
#  1,
#  3,
#  3,
#  6,
#  2,
#  4,
#  9,
#  9,
#  5,
#  4,
#  3,
#  6,
#  7,
#  4,
#  6,
#  8,
#  5,
#  5,
#  4,
#  3,
#  1,
#  8,
#  4,
#  7,
#  6,
#  0,
# ...
